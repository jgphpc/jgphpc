# %% [markdown]
# # SPH-EXA miniapp csv

# %%
# %matplotlib notebook
# https://matplotlib.org/api/_as_gen/mpl_toolkits.mplot3d.axes3d.Axes3D.html?highlight=scatter3d#mpl_toolkits.mplot3d.axes3d.Axes3D.scatter3D
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm # colorbar
import pandas as pd
import matplotlib.pyplot as plt

# %%
headers = ['x', 'y', 'z', 'vx', 'vy', 'vz', 'h', 'rho', 'u', 'p', 'c', 
           'gradPx', 'gradPy', 'gradPz', 'rad', 'vrad']
csvfile = '/tmp/dump0.txt'
# csvfile = '/tmp/dump600.txt'
# ./bin/jgm_GNU_mac.exe -n 10 -s 600 -w 10
# 1 line per particle, 1000 particles
df  = pd.read_csv(csvfile, sep=' ', names=headers)

# %%
print(type(df))
print(df.head(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
#          x        y   z       vx       vy            vz   h       rho  \
# 0  70.7393  33.8081 -45  153.907 -264.766 -7.655040e-14  25  0.472609
# 1  65.8260  26.5027 -45  124.964 -242.760  1.694590e-15  25  0.641093
#
#          u        p     c    gradPx   gradPy        gradPz      rad     vrad
# 0  3.00670 -7451.94  3500  1053.500  564.105  3.572350e-11  90.3993  21.4162
# 1  7.39706 -8216.36  3500   943.129  456.728 -7.908100e-13  84.0265  21.3276

# %%
xx = df['x']
yy = df['y']
zz = df['z']
cc = df['p']

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# ax.scatter3D(xx, yy, zz, c=cc)
# ax.legend(loc='best')
ax.scatter3D(xx, yy, zz, c=cc, cmap='viridis')
# https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
# ax.set_xlim(-1, 1);

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='plasma')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='inferno')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='magma')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='cividis')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='Greys')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='Purples')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='Blues')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='Greens')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='Oranges')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='Reds')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='YlOrBr')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='YlOrRd')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='OrRd')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='PuRd')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='RdPu')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='BuPu')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='GnBu')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='PuBu')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='YlGnBu')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='PuBuGn')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='BuGn')

# %%
ax.scatter3D(xx, yy, zz, c=cc, cmap='YlGn')

# %%
# "234" means "2x3 grid, 4th subplot".
plt.subplot(221)
csvfile = '/tmp/dump0.txt'
df  = pd.read_csv(csvfile, sep=' ', names=headers)
xx = df['x']
yy = df['y']
pp = df['p']
cm = plt.cm.get_cmap('RdYlBu')
sc=plt.scatter(xx, yy, c=pp)
plt.colorbar(sc)

plt.subplot(222)
csvfile = '/tmp/dump200.txt'
df  = pd.read_csv(csvfile, sep=' ', names=headers)
xx = df['x']
yy = df['y']
pp = df['p']
cm = plt.cm.get_cmap('RdYlBu')
sc=plt.scatter(xx, yy, c=pp)
plt.colorbar(sc)

plt.subplot(223)
csvfile = '/tmp/dump400.txt'
df  = pd.read_csv(csvfile, sep=' ', names=headers)
xx = df['x']
yy = df['y']
pp = df['p']
cm = plt.cm.get_cmap('RdYlBu')
sc=plt.scatter(xx, yy, c=pp)
plt.colorbar(sc)

plt.subplot(224)
csvfile = '/tmp/dump600.txt'
df  = pd.read_csv(csvfile, sep=' ', names=headers)
xx = df['x']
yy = df['y']
pp = df['p']
cm = plt.cm.get_cmap('RdYlBu')
sc=plt.scatter(xx, yy, c=pp)
plt.colorbar(sc)

plt.show()

# %%
plt.subplot(111)
csvfile = '/tmp/dump200.txt'
df  = pd.read_csv(csvfile, sep=' ', names=headers)
xx = df['x']
yy = df['y']
pp = df['p']

# from matplotlib import cm
cm = plt.cm.get_cmap('RdYlBu')
sc=plt.scatter(xx, yy, c=pp)
plt.colorbar(sc)

# %%
import numpy as np
np.random.seed(19680801)

plt.subplot(121)
plt.imshow(np.random.random((100, 100)), cmap=plt.cm.BuPu_r)
plt.subplot(122)
plt.imshow(np.random.random((100, 100)), cmap=plt.cm.BuPu_r)

plt.subplots_adjust(bottom=0.1, right=0.8, top=0.9)
cax = plt.axes([0.85, 0.1, 0.075, 0.8])
plt.colorbar(cax=cax)
plt.show()
